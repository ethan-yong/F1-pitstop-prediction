# %% [markdown]
# # Pull reference kernel
#
# Downloads [anthonytherrien/predicting-f1-pit-stops-xgboost](https://www.kaggle.com/code/anthonytherrien/predicting-f1-pit-stops-xgboost) into `reference_kernel/`.
#
# Requires Kaggle credentials (`kaggle auth login` once in terminal if pull fails).

# %%
# !kaggle kernels pull anthonytherrien/predicting-f1-pit-stops-xgboost -p reference_kernel
# Out:
# Source code downloaded to reference_kernel\predicting-f1-pit-stops-xgboost.ipynb

# %%
from pathlib import Path

out = Path("reference_kernel")
files = sorted(p for p in out.rglob("*") if p.is_file())
if not files:
    raise FileNotFoundError("Nothing in reference_kernel/ — run the pull cell above.")

print(f"Downloaded {len(files)} file(s):")
for p in files:
    print(f"  {p.relative_to(out)}")
# Out:
# Downloaded 3 file(s):
#   predicting-f1-pit-stops-xgboost.ipynb
#   vault\submission (1).csv
#   vault\submission.csv
